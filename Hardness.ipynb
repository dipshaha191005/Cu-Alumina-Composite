# %% [markdown]
# <a href="https://colab.research.google.com/github/dipshaha191005/Cu-Alumina-Composite/blob/main/Hardness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab import files

# %% [markdown]
# # Loading Files

# %%
# Upload the Excel file manually
uploaded = files.upload()

# Get the filename
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename, sheet_name="Only Aged data")
df
# Out:
#      <input type="file" id="files-9c1344b6-cc5e-460f-849b-7d02e02d3124" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c1344b6-cc5e-460f-849b-7d02e02d3124">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Variation with Aging Temperature

# %%
#colors = ['red', 'blue', 'green', 'orange']

# Extract aging temperature (first column)
aging_temp = df.iloc[:, 0]

plt.figure(figsize=(9,6))

# ----- LOOP THROUGH ALL OTHER COLUMNS -----
for col in df.columns[1:]:   # skip the first column
    plt.plot(aging_temp, df[col], marker='o', linewidth=2, label=col)
# ------------------------------------------

plt.xlabel('Aging Temperature (°C)', fontsize=13, fontweight='bold')
plt.ylabel('Microhardness (HV)', fontsize=13, fontweight='bold')
plt.title('Hardness vs Aging Temperature', fontsize=14, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.4)
plt.ylim(60, 120)        # y-axis range
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Variation with Rolling

# %%
# Get the filename
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename, sheet_name="Rolled data")
df
# Out:
#   Rolling deformation  0% Alumina  .05% Alumina  0.1% Alumina  .5% alumina  \
# 0           0% Rolled   72.108000     78.253656     80.320000    81.834667
# 1          15% Rolled  133.281333    110.921764    137.748200   148.862000
# 2          30% Rolled  140.194800    117.940028    139.992200   165.410600
# 3         37%% Rolled  162.491628    160.500000    161.856935   167.980349
# 4          50% Rolled  119.146963    146.139747    143.059723   145.554321
#
#    1% Alumina
# 0   85.107000
# 1  130.107200
# 2  151.157600
# 3  142.799213
# 4  125.960240

# %%
#Extract Different Rolling
rolling_deformation = df.iloc[:, 0]

plt.figure(figsize=(9,6))

# ----- LOOP THROUGH ALL OTHER COLUMNS -----
for col in df.columns[1:]:   # skip the first column
    plt.plot(rolling_deformation, df[col], marker='o', linewidth=2, label=col)
# ------------------------------------------

plt.xlabel('Rolling Deformation of thickness (%)', fontsize=13, fontweight='bold')
plt.ylabel('Microhardness (HV)', fontsize=13, fontweight='bold')
plt.title('Hardness vs Rolling Deformation', fontsize=14, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.4)
plt.ylim(50, 200)        # y-axis range
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Variation with aging temperature after 50% Rolling

# %%
# Get the filename
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename, sheet_name="45% Rolled+ Aging")
df
# Out:
#   45% rolling+ Aging  0% alumina  .05% alumina  .1% alumina  .5% alumina  \
# 0           no aging  119.146963    146.139747   143.059723   145.554321
# 1               100C  140.193059    148.957576   150.362419   158.497512
# 2               200C  125.281886    127.297326   143.415796   143.407173
# 3               300C  123.926279     96.028402   140.338779   126.625572
# 4               400C   85.204019     81.530052    85.380004    72.909055
#
#    1.0% alumina
# 0    125.960240
# 1    140.500000
# 2    120.170624
# 3     88.375053
# 4     90.501434

# %%
#Extract Different Rolling
rolling_aging_temp = df.iloc[:, 0]

plt.figure(figsize=(9,6))

# ----- LOOP THROUGH ALL OTHER COLUMNS -----
for col in df.columns[1:]:   # skip the first column
    plt.plot(rolling_aging_temp, df[col], marker='o', linewidth=2, label=col)
# ------------------------------------------

plt.xlabel('Aging Temp After 50% rolling Deformation of thickness (T)', fontsize=13, fontweight='bold')
plt.ylabel('Microhardness (HV)', fontsize=13, fontweight='bold')
plt.title('Hardness vs Aging after Rolling Deformation', fontsize=14, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.4)
plt.ylim(30,170)        # y-axis range
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Change with Time Variation of aging

# %%
# Get the uploaded file name (assuming it's the first file uploaded)
file_path = list(uploaded.keys())[0]

# Load all sheets in the Excel file into a dictionary
dfs = pd.read_excel(file_path, sheet_name=['100', '300', '500','700'])

# %%
# Define different marker styles
markers = ['o', 's', '^', 'D', 'x']  # Add more markers if needed
colors = ['blue', 'orange', 'green', 'red','black']

# Iterate through each sheet (temperature)
for temp, df in dfs.items():
    # Create a new figure for each temperature
    plt.figure(figsize=(8,5))

    # Extract the aging time (assuming it's the first column)
    aging_time = df.iloc[:, 0].values  # Get the first column for aging time

    # Plot data for each material (assuming each material is a column after the first)
    for i, col in enumerate(df.columns[1:]):
        # Convert the column to numeric, coercing errors to NaN
        conductivity = pd.to_numeric(df[col], errors='coerce').values
        marker = markers[i % len(markers)]  # Cycle through marker styles if more than 5 materials
        # Corrected line: pass a single color from the list based on the index 'i'
        plt.plot(aging_time, conductivity, label=col, color=colors[i % len(colors)], marker=marker, markersize=6, linestyle='-', linewidth=2)

    # Set the title and labels

    plt.xlabel('Aging Time (hours)',fontsize=14, fontweight='bold')
    plt.ylabel('Microhardness (HV)',fontsize=14, fontweight='bold')
    plt.legend()
    plt.title(f'at {temp}C', fontsize=16, fontweight='bold')
    plt.grid(True, linestyle='--', alpha=0.4)
    # Set y-axis limits to 60 to 110 for consistency
    plt.ylim(50, 120)

    # Set x-axis to display the actual aging time values, starting from 0
    plt.xlim(left=0)  # Ensure the x-axis starts from 0



    # Display the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 50% rolled composite with different temperature of aging

# %%
filename = list(uploaded.keys())[0]

df = pd.read_excel(filename, sheet_name="only .05% Al2O3")
df
# Out:
#     Temp         avg  error
# 0  25 C   146.139747   2.46
# 1  100 C  148.957576   2.46
# 2  200 C  127.297326   2.46
# 3  300 C   96.028402   2.46
# 4  400 C   81.530052   2.46
# 5  500 C   75.823022   2.46
# 6  600 C   84.827480   2.46
# 7  700 C   75.792767   2.46
# 8  800 C   74.497300   2.46

# %%
x = df['Temp']
y = df['avg']
err = df['error']

plt.figure(figsize=(8,6))

# Labeling
plt.xlabel('Aging temperature (C)', fontsize=13)
plt.ylabel('Microhardness (HV)', fontweight='bold', fontsize=13)
plt.title(f'aging of 50% rolled sample of .05% alumina composite')

# --- Line diagram with error bars ---
plt.plot(x, y, marker='o', linestyle='-', linewidth=2)        # line + markers
plt.errorbar(x, y, yerr=err, fmt='o', capsize=5, ecolor='black')

# Y-axis limit
plt.ylim(40, 160)

# Grid
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()
